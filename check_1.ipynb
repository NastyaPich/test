# %%
print('123')
# Out:
# 123

# %%
цифры = input("Введите строку цифр: ")
количество_четных = sum(1 for цифра in цифры if цифра in "02468")

print("Количество четных цифр:", количество_четных)
# Out:
# Количество четных цифр: 9
